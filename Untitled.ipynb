# %%
import pandas as pd
from geopy.geocoders import Nominatim
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('covid_19_data.csv')

# %%
unique_countries = df['Country/Region'].unique()

# %%
l = []

for country in unique_countries:
    max_value = df[df['Country/Region'] == country].Confirmed.max()
    l.append([country, max_value])
    
df_countries = pd.DataFrame(l, columns=("Country", "Confirmed"))
df_countries
# Out:
#              Country  Confirmed
# 0     Mainland China    67760.0
# 1          Hong Kong      115.0
# 2              Macau       10.0
# 3             Taiwan       45.0
# 4                 US      267.0
# ..               ...        ...
# 125     Burkina Faso        1.0
# 126  Channel Islands        1.0
# 127         Holy See        1.0
# 128         Mongolia        1.0
# 129           Panama        1.0
#
# [130 rows x 2 columns]

# %%
geolocator = Nominatim()
plt.figure(figsize=(16,10))

def mapTut():

    m = Basemap(projection='mill',llcrnrlat=-60,urcrnrlat=90,\
                llcrnrlon=-180,urcrnrlon=180,resolution='c')
    m.drawcoastlines()
    m.drawcountries()
    m.fillcontinents(color='#04BAE3',lake_color='#FFFFFF')
    m.drawmapboundary(fill_color='#FFFFFF')

    for index in range(df_countries['Country'].size):
    #index = 0
    #for index in range(10):
    
        country = df_countries['Country'][index]
        confirmed = df_countries['Confirmed'][index]
        location = geolocator.geocode(country)[1]

        lat, lon = location[0], location[1]
        x, y = m(lon, lat)
        print(country, confirmed)

        m.plot(x, y, 'r.', markersize=(60.0/67760.0)*confirmed + 15.0)
        #index += 1

    plt.title("Geo Plotting")
    plt.show()


mapTut()
# Out:
# /home/bionic/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Using Nominatim with the default "geopy/1.21.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   """Entry point for launching an IPython kernel.
# Mainland China 67760.0
# Hong Kong 115.0
# Macau 10.0
# Taiwan 45.0
# US 267.0
# Japan 581.0
# Thailand 53.0
# South Korea 7478.0
# Singapore 160.0
# Philippines 33.0
# Malaysia 129.0
# Vietnam 30.0
# Australia 55.0
# Mexico 7.0
# Brazil 31.0
# Colombia 3.0
# France 1784.0
# Nepal 1.0
# Canada 36.0
# Cambodia 2.0
# Sri Lanka 1.0
# Ivory Coast 1.0
# Germany 1457.0
# Finland 40.0
# United Arab Emirates 74.0
# India 56.0
# Italy 10149.0
# UK 382.0
# Russia 17.0
# Sweden 355.0
# Spain 1695.0
# Belgium 267.0
# Others 706.0
# Egypt 59.0
# Iran 7161.0
# Israel 58.0
# Lebanon 41.0
# Iraq 71.0
# Oman 18.0
# Afghanistan 5.0
# Bahrain 110.0
# Kuwait 69.0
# Austria 182.0
# Algeria 20.0
# Croatia 14.0
# Switzerland 491.0
# Pakistan 16.0
# Georgia 15.0
# Greece 89.0
# North Macedonia 7.0
# Norway 400.0
# Romania 25.0
# Denmark 262.0
# Estonia 12.0
# Netherlands 382.0
# San Marino 51.0
#  Azerbaijan 1.0
# Belarus 9.0
# Iceland 69.0
# Lithuania 1.0
# New Zealand 5.0
# Nigeria 2.0
# North Ireland 1.0
# Ireland 34.0
# Luxembourg 5.0
# Monaco 1.0
# Qatar 24.0
# Ecuador 15.0
# Azerbaijan 11.0
# Czech Republic 41.0
# Armenia 1.0
# Dominican Republic 5.0
# Indonesia 27.0
# Portugal 41.0
# Andorra 1.0
# Latvia 8.0
# Morocco 3.0
# Saudi Arabia 20.0
# Senegal 4.0
# Argentina 17.0
# Chile 13.0
# Jordan 1.0
# Ukraine 1.0
# Saint Barthelemy 3.0
# Hungary 9.0
# Faroe Islands 2.0
# Gibraltar 1.0
# Liechtenstein 1.0
# Poland 22.0
# Tunisia 5.0
# Palestine 22.0
# Bosnia and Herzegovina 5.0
# Slovenia 31.0
# South Africa 7.0
# Bhutan 1.0
# Cameroon 2.0
# Costa Rica 9.0
# Peru 11.0
# Serbia 5.0
# Slovakia 7.0
# Togo 1.0
# Vatican City 1.0
# French Guiana 5.0
# Malta 5.0
# Martinique 2.0
# Republic of Ireland 21.0
# Bulgaria 4.0
# Maldives 6.0
# Bangladesh 3.0
# Moldova 1.0
# Paraguay 1.0
# Albania 10.0
# Cyprus 3.0
# St. Martin 2.0
# Brunei 1.0
# Iran (Islamic Republic of) 8042.0
# Republic of Korea 7513.0
# Hong Kong SAR 120.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-5d962f4ab910> in <module>
#      30
#      31
# ---> 32 mapTut()
#
# <ipython-input-34-5d962f4ab910> in mapTut()
#      17         country = df_countries['Country'][index]
#      18         confirmed = df_countries['Confirmed'][index]
# ---> 19         location = geolocator.geocode(country)[1]
#      20
#      21         lat, lon = location[0], location[1]
#
# TypeError: 'NoneType' object is not subscriptable
